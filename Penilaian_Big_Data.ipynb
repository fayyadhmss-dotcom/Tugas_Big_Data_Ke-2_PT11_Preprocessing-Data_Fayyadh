# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('/content/tugas bu meita1.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print (X)
# Out:
# []

# %%
print (y)
# Out:
# ['1;andi;25;magelang;1.500.000' '2;budi;;bandung;2.200.000'
#  '3;citra;28;jakarta;' '4;deni;35;surabaya;2.750.000'
#  '5;eka;;medan;1.000.000' '6;fajar;32;jogja;2.000.000'
#  '7;gina;24;semarang;3.000.000' '8;hadi;29;makasar;4.000.000'
#  '9;intan;31;bali;5.000.000' '10;joko;26;palembang;6.000.000']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, 1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1795/2241950577.py in <cell line: 0>()
#       1 from sklearn.impute import SimpleImputer
#       2 imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 3 imputer.fit(X[:, 1:3])
#       4 X[:, 1:3] = imputer.transform(X[:, 1:3])
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py in fit(self, X, y)
#     432             Fitted estimator.
#     433         """
# --> 434         X = self._validate_input(X, in_fit=True)
#     435
#     436         # default fill_value is 0 for numerical input and "missing_value"
#
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py in _validate_input(self, X, in_fit)
#     361                 raise new_ve from None
#     362             else:
# --> 363                 raise ve
#     364
#     365         if in_fit:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/impute/_base.py in _validate_input(self, X, in_fit)
#     342
#     343         try:
# --> 344             X = validate_data(
#     345                 self,
#     346                 X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1137         n_features = array.shape[1]
#    1138         if n_features < ensure_min_features:
# -> 1139             raise ValueError(
#    1140                 "Found array with %d feature(s) (shape=%s) while"
#    1141                 " a minimum of %d is required%s."
#
# ValueError: Found array with 0 feature(s) (shape=(10, 0)) while a minimum of 1 is required by SimpleImputer.
